# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-experimental
# !pip install google-generativeai
# !pip install langchain-google-genai
# !pip install pypdf
# !pip install unstructured
# !pip install openpyxl
# !pip install docx2txt
# !pip insttall python-magic
# !pip install python-pptx
# !pip install faiss-cpu
# !pip install tiktoken
# !pip install -U langchain-openai
# Out:
# ...
# ERROR: unknown command "insttall" - maybe you meant "install"
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from langchain_core.prompts import PromptTemplate
from langchain.chains.llm import LLMChain
from langchain_core.prompts import ChatPromptTemplate

# %%
os.environ['GOOGLE_API_KEY']='AIzaSyBxpx1hO5zF3AmPzuFNYUpGSDEINeqbvJw'
llm=ChatGoogleGenerativeAI(model='gemini-1.5-flash-latest')

prompt_template='Tell me a joke about {object}'
prompt=PromptTemplate(template=prompt_template,input_variabels=['object'])
llm_chain=prompt | llm
response=llm_chain.invoke({'object':'dog'})
print(response)
# Out:
# content='Why are dogs such bad dancers?  Because they have two left feet!\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run-1cdbf2c4-5241-4a38-9fee-ac04e7d61976-0' usage_metadata={'input_tokens': 7, 'output_tokens': 16, 'total_tokens': 23, 'input_token_details': {'cache_read': 0}}

# %%
chat_prompt_template=ChatPromptTemplate([
    ("system","Generate a joke about input from the given user"),
    ("human","{input}")
])
llm_chain=chat_prompt_template | llm
response=llm_chain.invoke({"input":"dogs"})
print(response)
# Out:
# content='Why are dogs such bad dancers?  Because they have two left feet... and two more!\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run-9bb95762-c7a4-48f0-9437-4aade442ab05-0' usage_metadata={'input_tokens': 11, 'output_tokens': 20, 'total_tokens': 31, 'input_token_details': {'cache_read': 0}}
